# %% [markdown]
# <a href="https://colab.research.google.com/github/Agnaputra/PCVK_Ganjil_2025_01/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
import numpy as np
from google.colab.patches import cv2_imshow  # jika memakai Google Colab

print('Mengubah tingkat kecerahan citra')

try:
    brightness = int(input('Masukkan nilai kecerahan: '))
except ValueError:
    print('Error, not a number')
    brightness = 0  # nilai default jika input salah

# Membaca citra asli
original = cv.imread('/content/drive/MyDrive/Images/female.jpg')
brightness_image = np.zeros(original.shape, original.dtype)

# Akses per piksel (manual)
for y in range(original.shape[0]):
    for x in range(original.shape[1]):
        for c in range(original.shape[2]):
            brightness_image[y, x, c] = np.clip(original[y, x, c] + brightness, 0, 255)

# Cara simple tanpa for loop (alternatif):
# brightness_image = cv.convertScaleAbs(original, beta=brightness)

# Gabungkan hasil sebelum dan sesudah
final_frame = cv.hconcat([original, brightness_image])
cv2_imshow(final_frame)
# Out:
# Mengubah tingkat kecerahan citra
# Masukkan nilai kecerahan: 50
# /tmp/ipython-input-436458468.py:21: RuntimeWarning: overflow encountered in scalar add
#   brightness_image[y, x, c] = np.clip(original[y, x, c] + brightness, 0, 255)
# <PIL.Image.Image image mode=RGB size=518x194>
